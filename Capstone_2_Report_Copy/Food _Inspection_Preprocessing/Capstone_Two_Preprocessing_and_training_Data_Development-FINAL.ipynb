# %% [markdown]
# # Overview
# The objective of this notebook is to perform data pre-processing on the dataset from Capstone 2 Exploratory Data Analysis(EDA) to prepare it for modelling by clustering.
#
# The process will involve creating dummy features and splitting of data into training and testing subsets.
#
# Inspection comments (and other variables) will be used in the dataframe containing food safety scores (scores_df) to determine if inspection scores or grades can be predicted from features such as inspection comments, date of inspection, type of water, area code, etc.

# %%
# Install librtaries
! pip install wordcloud

# Import relevant libraries and packages.

# Basic libraries
import numpy as np 
import pandas as pd 

# Vizualization
import matplotlib.pyplot as plt 
import seaborn as sns 
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# Text analysis
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import punkt
from nltk import punkt
from nltk import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
import re 

# Model pre-processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# For handling error messages.
import warnings 

# Don't worry about the following two instructions: they just suppress warnings that could occur later. 
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")
from os import path
# Out:
# Requirement already satisfied: wordcloud in c:\users\fabby\anaconda3\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\fabby\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\fabby\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\fabby\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fabby\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\fabby\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# First import two spreadsheets into the dataframe. 'allinspections_eda.csv' contains the resultant dataframe from EDA and will be used to train the data. The second spreadsheet, 'food-health-inspections_3.csv' will be used to test the model in the future.

# %%
# Read in all the csv files

# food-health-inspections_3 contains information about different kind of establishments, inspection scores, inspection comments,
# date of inspection, etc.
scores_df = pd.read_csv('food-health-inspections_3.csv')
# Out:
# C:\Users\fabby\AppData\Local\Temp\ipykernel_53788\501540096.py:5: DtypeWarning: Columns (87) have mixed types. Specify dtype option on import or set low_memory=False.
#   scores_df = pd.read_csv('food-health-inspections_3.csv')

# %%
# Creat word clouds by type of establishment

# Cycle through each establishment type, create a dataframe of the lemmas for each type and plot it
def create_wordcloud(df, establishments, lemma_col):
    for item in establishments:
        dframe = df[df['rpt_area_desc'] == item]
        text = ' '.join(lemma for lemma in dframe[lemma_col]) # Create text for each establishment type
        wordcloud = WordCloud(background_color = 'white', max_words = 200).generate(text) # Create and generate a word cloud image
        plt.imshow(wordcloud, interpolation = 'bilinear')
        plt.axis('off')
        plt.title(item)
        plt.show()

# %% [markdown]
# Inspect the scores_df dataframe, the clean and split into training and test sets.

# %%
# Inspect the columns of scores_df
scores_df.head(1)
# Out:
#    index  update_user_id  score_sum end_inspection_ampm comments  seats  \
# 0      0             NaN      100.0                 NaN      NaN    NaN
#
#    com_num premise_name delete_mark  travel_time_min  ...  mileage  \
# 0      NaN          NaN      ACTIVE              0.0  ...      NaN
#
#    permit_status_id  ampm_of_inspection  followup_id  rpt_area_desc  \
# 0               1.0                 NaN           NO   Food Service
#
#    time_of_inspection  chlorine_sum  bromine_sum  est_group_id  \
# 0                 NaN           NaN          NaN           NaN
#
#   inspection_reason_desc
# 0                    NaN
#
# [1 rows x 88 columns]

# %%
# Print out details of the columns of scores_df
scores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112046 entries, 0 to 112045
# Data columns (total 88 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   index                       112046 non-null  int64
#  1   update_user_id              45304 non-null   float64
#  2   score_sum                   96946 non-null   float64
#  3   end_inspection_ampm         33162 non-null   object
#  4   comments                    20979 non-null   object
#  5   seats                       2330 non-null    float64
#  6   com_num                     0 non-null       float64
#  7   premise_name                15689 non-null   object
#  8   delete_mark                 112046 non-null  object
#  9   travel_time_min             107515 non-null  float64
#  10  biguanide_sum               35 non-null      float64
#  11  action_code_desc            0 non-null       float64
#  12  travel_time_hrs             107515 non-null  float64
#  13  water_temp_sum              779 non-null     float64
#  14  epi_type_id                 48332 non-null   float64
#  15  sewage                      112046 non-null  int64
#  16  ehs_num                     0 non-null       float64
#  17  classification_id           3767 non-null    float64
#  18  insp_type                   112046 non-null  int64
#  19  type_description            112046 non-null  object
#  20  field59                     0 non-null       float64
#  21  time_of_inspection_hr       36842 non-null   float64
#  22  insp_date                   112046 non-null  object
#  23  num_repeat_rf_inter_viol    13631 non-null   float64
#  24  est_type_num                0 non-null       float64
#  25  est_type                    112046 non-null  int64
#  26  rpt_area_num                0 non-null       float64
#  27  action_code_id              0 non-null       float64
#  28  permit_type_id              0 non-null       float64
#  29  complaint_section           0 non-null       float64
#  30  water                       112046 non-null  int64
#  31  rpt_area_code               112046 non-null  int64
#  32  person_incharge_fname       6000 non-null    object
#  33  est_id                      112046 non-null  int64
#  34  water_ph_sum                3641 non-null    float64
#  35  end_time_of_inspection_hh   33213 non-null   float64
#  36  inspection_time_min         107518 non-null  float64
#  37  num_rf_inter_viol           17739 non-null   float64
#  38  extra_credit                112046 non-null  object
#  39  origin                      112046 non-null  int64
#  40  geolocation                 15623 non-null   object
#  41  grade                       55238 non-null   object
#  42  est_group_desc              2503 non-null    object
#  43  oss_id                      0 non-null       float64
#  44  county                      112046 non-null  int64
#  45  verification_required_date  1019 non-null    object
#  46  void_date                   0 non-null       float64
#  47  update_date                 112046 non-null  object
#  48  epi_type_desc               0 non-null       float64
#  49  ehs                         112046 non-null  int64
#  50  district                    112045 non-null  float64
#  51  person_incharge_lname       5919 non-null    object
#  52  territory                   48331 non-null   float64
#  53  end_time_of_inspection_mm   33195 non-null   float64
#  54  inspection_reason_id        66 non-null      float64
#  55  cdp_est_num                 1 non-null       float64
#  56  est_num                     112034 non-null  float64
#  57  oss_num                     0 non-null       float64
#  58  final_score_sum             96946 non-null   float64
#  59  image_file_name             31558 non-null   object
#  60  image_file_path             31558 non-null   object
#  61  ehs_id                      112046 non-null  int64
#  62  six_point_demerit           112046 non-null  object
#  63  group_code_id               75920 non-null   float64
#  64  request_number              0 non-null       float64
#  65  state_id                    112046 non-null  int64
#  66  smoking_allowed             2332 non-null    object
#  67  classification_desc         3767 non-null    object
#  68  permit_status               0 non-null       float64
#  69  sample_attendance           0 non-null       float64
#  70  sample                      112046 non-null  object
#  71  comment_sheet_id            112046 non-null  object
#  72  sent_to_bets_yn             112046 non-null  object
#  73  id                          112046 non-null  int64
#  74  violations_id               112046 non-null  int64
#  75  inspection_time_hrs         107519 non-null  float64
#  76  setup_date                  112046 non-null  object
#  77  time_of_inspection_mm       36821 non-null   float64
#  78  mileage                     0 non-null       float64
#  79  permit_status_id            112045 non-null  float64
#  80  ampm_of_inspection          34382 non-null   object
#  81  followup_id                 112046 non-null  object
#  82  rpt_area_desc               112046 non-null  object
#  83  time_of_inspection          31827 non-null   float64
#  84  chlorine_sum                3444 non-null    float64
#  85  bromine_sum                 96 non-null      float64
#  86  est_group_id                2503 non-null    float64
#  87  inspection_reason_desc      66 non-null      object
# dtypes: float64(47), int64(14), object(27)
# memory usage: 75.2+ MB

# %% [markdown]
# There are 87 features in the scores_df. We will take a closer look at the values in each of these columns and determine which do not add information for the analysis.

# %%
#Calculate percentage of null values in each column
def print_pctnull(df):
    pct = round((df.isnull().sum()/len(df)*100),1).sort_values(ascending = False)
    for idx,ent in zip(pct.index, pct.to_numpy()):
        print(idx + ': ' + str(ent))

# print percentage of nulls in df 
print_pctnull(scores_df)
# Out:
# epi_type_desc: 100.0
# complaint_section: 100.0
# action_code_id: 100.0
# rpt_area_num: 100.0
# mileage: 100.0
# est_type_num: 100.0
# permit_status: 100.0
# oss_id: 100.0
# field59: 100.0
# void_date: 100.0
# ehs_num: 100.0
# permit_type_id: 100.0
# oss_num: 100.0
# action_code_desc: 100.0
# sample_attendance: 100.0
# biguanide_sum: 100.0
# cdp_est_num: 100.0
# request_number: 100.0
# com_num: 100.0
# inspection_reason_id: 99.9
# inspection_reason_desc: 99.9
# bromine_sum: 99.9
# water_temp_sum: 99.3
# verification_required_date: 99.1
# seats: 97.9
# smoking_allowed: 97.9
# est_group_desc: 97.8
# est_group_id: 97.8
# chlorine_sum: 96.9
# water_ph_sum: 96.8
# classification_desc: 96.6
# classification_id: 96.6
# person_incharge_lname: 94.7
# person_incharge_fname: 94.6
# num_repeat_rf_inter_viol: 87.8
# geolocation: 86.1
# premise_name: 86.0
# num_rf_inter_viol: 84.2
# comments: 81.3
# image_file_path: 71.8
# image_file_name: 71.8
# time_of_inspection: 71.6
# end_inspection_ampm: 70.4
# end_time_of_inspection_hh: 70.4
# end_time_of_inspection_mm: 70.4
# ampm_of_inspection: 69.3
# time_of_inspection_hr: 67.1
# time_of_inspection_mm: 67.1
# update_user_id: 59.6
# epi_type_id: 56.9
# territory: 56.9
# grade: 50.7
# group_code_id: 32.2
# final_score_sum: 13.5
# score_sum: 13.5
# travel_time_hrs: 4.0
# travel_time_min: 4.0
# inspection_time_hrs: 4.0
# inspection_time_min: 4.0
# id: 0.0
# rpt_area_desc: 0.0
# sent_to_bets_yn: 0.0
# setup_date: 0.0
# permit_status_id: 0.0
# comment_sheet_id: 0.0
# sample: 0.0
# followup_id: 0.0
# violations_id: 0.0
# index: 0.0
# state_id: 0.0
# rpt_area_code: 0.0
# delete_mark: 0.0
# sewage: 0.0
# insp_type: 0.0
# type_description: 0.0
# insp_date: 0.0
# est_type: 0.0
# water: 0.0
# est_id: 0.0
# six_point_demerit: 0.0
# extra_credit: 0.0
# origin: 0.0
# update_date: 0.0
# ehs: 0.0
# district: 0.0
# est_num: 0.0
# ehs_id: 0.0
# county: 0.0

# %%
# Print unique values for each column
df_score_columns = scores_df.columns

for column in df_score_columns:
    print(column + ': ' + str(scores_df[column].unique()))
# Out:
# index: [     0      1      2 ... 112043 112044 112045]
# seats: [ nan  50.   0.  34.  36.   4.   3. 165.  90.  15.  75. 200. 120.  76.
#   54.   6.  44. 100.  10.   2. 118.  70.  55.  81. 144.  96.  25.  45.
#   37.  31.   8. 246.  43. 208.  93.  28.  80. 240.  32.  99. 236. 150.
#   22.  42.  33.  85.  48.  14. 190.  35.  71.  62.  27. 300.   5. 138.
#   49.  40.  30.  20.  52.  26. 132.  73.  65. 270.  23. 110.   1.  16.
#   86.  47.  53.  24. 350.  92.   9.  67. 250. 160.  39.  19.  60.  11.
#   78. 228.  94. 180.  98.  18.  57. 187. 242.  56.  88.  84. 105. 248.
#  114. 134.  63. 225. 235. 176.   7. 266. 170. 106. 199. 123.  68.  72.
#  140. 290. 252. 112. 360.  29.  12.  58. 104. 194. 175. 142.  64. 135.
#  164. 145.  69. 137.  38. 125.  87. 212. 128. 256.]
# com_num: [nan]
# premise_name: [nan 'COSTCO  FOOD COURT 249' 'MAYFLOWER SEAFOOD  16' 'CHICK FIL A'
#  'SPRING ARBOR OF DURHAM' 'KINDRED TRANS CARE& REHAB-ROSE MANOR'
#  'BROOKDALE CHAPEL HILL - AL' 'DURHAM RIDGE ASSISTED LIVING'
#  'EDEN SPRING LIVING CENTER' 'DUKE HOSPITAL NORTH' 'THE ASBURY PRE SCHOOL'
#  'BRIGHT HORIZONS AT NORTH DURHAM' "BROWN'S EARLY LEARNING SCHOOL"
#  'ACADEMY OF STARS' 'BRIGHT HORIZONS @ THE ENRICHMENT CENTER'
#  'GORMAN EARLY LEARNING CENTER' 'SATISFACTION RESTAURANT AND BAR'
#  'DUKE HOSPITAL-NORTH CAFE' 'BROOKDALE MEMORY CHAPEL HILL IFS'
#  'CAMILLA GARDENS IFS' 'ELLISON REST HOME IFS' 'FOOD LION MARKET 234'
#  'FOOD LION  MARKET 274' 'FOOD LION  MARKET 1099'
#  'FOOD LION MEAT MARKET #747' 'LA SUPERIOR MEAT MARKET'
#  'LOS PRIMOS SUPERMARKET' 'FOOD LION MEAT MARKET  2889'
#  'SUPER TARGET MEAT DEPT 2069' 'FOOD LION MEAT MARKET 2646'
#  'COMPARE FOODS MEAT MARKET' 'CARVER LIVING CENTER' 'CAMELLIA GARDENS'
#  'ELLISON REST HOME' 'FOREST AT DUKE' 'HILLCREST CONVALESCENT CENTER'
#  'PETTIGREW REHABILITATION CTR' 'PEARSONTOWN SCHOOL LUNCHROOM'
#  'RIVERSIDE SCHOOL LUNCHROOM' 'EXTENDED STAY AMERICA #201' 'WINGATE INN'
#  'MARRIOT DURHAM CITY CENTER' 'CANDLEWOOD SUITES' 'QUALITY INN & SUITES'
#  'MOTEL 6' 'LA QUINTA INN AND SUITES  184' 'RED ROOF INN'
#  "CAROL'S GARDEN INN" 'AVILA RETREAT CENTER' 'TESSIES DAY CARE'
#  'DOUBLETREE BY HILTON RDU' 'TOBACCO ROAD SPORTS CAFE'
#  'LENOX AT PATTERSON PLACE' 'PARKWOOD VILLAGE' 'SITAR INDIAN CUISINE'
#  'SANDERS CAFÉ AT GSK RTP' "BULL MCCABE'S" "S & D'S BOSS OF DOGS"
#  'WE BEA GRILLIN' 'SOUTH SQUARE TOWNHOMES' 'AMBER OAKS APARTMENTS'
#  "MONTESSORI  CHILDREN'S HOUSE OF DURHAM" 'PEPPERTREE'
#  'CHICK FIL A @ SOUTH SQUARE' 'BRIGHTLEAF CLUB WADING' 'CHUCK E CHEESE'
#  'P F CHANG S CHINA BISTRO' 'CARILLON ASSISTED LIVING OF DURHAM'
#  'GRILL 46' 'KFC' 'MILLENNIUM HOTEL POOL' 'JOHN AVERY BOYS & GIRLS'
#  'SUBWAY' 'HILTON GARDEN INN' 'TAQUERIA DON BERCERRA' 'ITALIAN PIZZERIA'
#  'HARRIS TEETER STARBUCKS' 'KROGER 332 SEAFOOD' 'CHILDCARE NETWORK # 166'
#  'PARKER & OTIS' 'NORTHSIDE BAPTIST' 'IHOP' 'RED MTN POOL'
#  'DURHAM CATERING CO.' "RANDY'S PIZZA" 'PHO 9N9'
#  'CHILD CARE SERVICES ASSOCIATION' 'POMODORO' "EL DORADO'S #6"
#  "DOMINO'S PIZZA" 'QUALITY MART  43' 'POMEGRANATE KITCHEN'
#  'THE LEARNING EXPERIENCE' 'TRIANGLE DAY SCHOOL' 'STONESTHROW APTS'
#  "CARLIE C'S IGA (MEAT MARKET)" 'TROSA' 'HARRIS TEETER #172 DELI'
#  'THE SAUCY CRAB' 'GG THE TASTE OF CHICAGO & FISH CHICKEN'
#  'UNC FSRA - MAIN' 'CROASDAILE COUNTRY CLUB'
#  'HOMESTEAD HEIGHTS SWIM AND TENNIS' 'COLONIAL VILLAGE AT WOOD LAKE'
#  'DURHAM CONVENTION CENTER' 'TOAST' 'EXTENDED STAY OF AMERICA'
#  'SPRINGHILL SUITES BY MARRIOTT' 'SUBWAY 29857' 'THE COOKERY'
#  "MAGGIANO'S LITTLE ITALY" 'T WEST KITCHEN' 'COMFORT INN - MEDICAL PARK'
#  'THE VEGAN LOVER' 'KURAMA' 'TAQUERIA MI PUEBLO' 'SALADELIA @ SANFORD'
#  'ONLY BURGER MFU DC #21' 'DOUBLE TREE SUITES - POOL' 'BIOGEN CAFE 35'
#  'LITTLE CAESARS PIZZA' 'L & D GROCERY & GRILL' 'SANSUI'
#  'THE PICKETT HOUSE FAMILY CARE HOME' "MCDONALD'S" 'FOOD LION DELI  #57'
#  'SPRINGHILL SUITES WEST POOL' 'SPRINGHILL SUITES WEST SPA'
#  'LEARNING TOTS ACADEMY' 'BULL CITY BURGER AND BREWERY' 'SCRATCH BAKING'
#  'TRINITY COMMONS SPA' 'PIE PUSHERS' 'PIZZERIA TORO' 'ELEMENTS'
#  'COMP COMM CARE INC-HICKORY GLEN HOUSE' 'EXTENDED STAY AMERICA #1570'
#  "STARBUCK'S COFFEE #10564" 'RUSSELL MEMORIAL DAY CARE' 'BURGER KING'
#  'A W NORTH CAROLINA' 'UNITED THERAPEUTICS' 'OLD HAVANA SANDWICH SHOP'
#  'DURHAM REGENT' 'SUBWAY 36194' 'BULL DURHAM BAR' 'BIO MERIEUX'
#  'PULCINELLA' 'HOLIDAY INN EXPRESS BREAKFAST BAR' 'LAQUINTA INN POOL'
#  'DUKE DIET & FITNESS CENTER' "MOE'S SOUTH WEST GRILL"
#  'KIDDIE KOLLEGE NO 2' 'CRAWLEY FAMILY CARE'
#  'SPRING VALLEY ELEMENTARY SCHOOL LUNCHROOM' 'FOREST OAKS TOWNHOMES'
#  'DANG GOOD DOGS' "ROMA'S PIZZA SHOP" 'REGIS AVENUE GROUP HOME'
#  'THIS LITTLE PIGGIE' 'LA SUPERIOR RESTAURANT' 'SAVANNAH PLACE'
#  'RENAISSANCE CENTRAL' 'PAPA JOHNS PIZZA'
#  'EXTENDED STAY AMERICA DELUXE - SOUTH' "TOP'S CHINA RESTAURANT"
#  'GREYSONS GREEN REC ASSOC' "DAME'S CHICKEN & WAFFLES"
#  'GREATER SAINT PAUL' "BANH'S CUISINE" 'MARRIOTT RTP SPA'
#  'KROGER 332 MEAT MARKET' 'SUBWAY  39636' "JOE'S DINER" 'HWY 55'
#  'NEO JAPAN' 'TACO BELL' 'SYMPATHY FOR THE DELI DC #84'
#  'CEDAR FORK BISTRO' 'FRANCESCAS' 'UMSTEAD PINES FORMERLY WILLOWHAVEN'
#  'HAMPTONS AT RTP' 'MISSION TRIANGLE POINT APTS' 'WYNDCROSS HOA'
#  'ATRIUM APTS' 'PARK PLACE REC ASSN' 'CROASDAILE APTS  2'
#  'DOWNING CREEK SWIM CLUB' 'SOUTHPOINT GLEN' 'HALGO EUROPEAN GROCERY'
#  'THE GODDARD SCHOOL' 'KROGER R/MEAT MARKET 337'
#  "HARDEE'S OF DUKE STREET  1613" 'NCCU PEARSON CAFETERIA' 'CHINO LATINO'
#  'PAN PAN DINER' 'SHERWOOD GITHENS MIDDLE SCHOOL LUNCH'
#  'EXTENDED STAY AMERICA #9836' "GOODBERRY'S CREAMERY" 'CREE CAFETERIA'
#  'LA COCINA #9' "JIMMY JOHN'S 991" 'KINGS RED AND WHITE/MEAT MARKET'
#  'TOM INSCOE WHOLESALE MEATS' 'FOOD LION  MARKET 939' "ARBY'S"
#  'MCDONALD  5234' 'NCCU CHILD DEVELOPMENT LAB'
#  'WHITE ROCK CHILD DEV CENTER' 'JEWISH COMMUNITY DAY SCHOOL'
#  'BUTTERFLY KISSES ACADEMY' 'GLENN ELEMENTARY SAC CLUB' 'HARDSCRABBLE HOA'
#  'HILTON GARDEN INN RAL/DUR/RTP POOL' 'SHERATON IMPERIAL'
#  'INNKEEPER SOUTH' 'LAKE RIDGE HOA' 'CRESTWOOD SUITES' 'MEWS APTS  THE'
#  'SUMMIT HILL' 'LOVE N JOY CHILD ACADEMY' 'LIBERTY BAPTIST DAY CARE'
#  'MANGUM ELEMENTARY SCI SAC CLU' 'BETHESDA ELEM SCHOOL' 'BURTON SCHOOL'
#  'DURHAM SCHOOL OF THE ARTS' 'FOREST VIEW ELEM SCH' 'R N HARRIS ELEM'
#  'LAKEWOOD ELEM SCHOOL' 'MANGUM SCHOOL' 'OAK GROVE SCHOOL'
#  'SHEPHARD MIDDLE SCHOOL' 'SHERWOOD GITHENS MIDDLE SCHOOL'
#  'SOUTHWEST ELEM SCHOOL' 'DURHAM ACADEMY' 'HILLSIDE NEW TECH.'
#  'CREEKSIDE ELEMENTARY' 'DURHAM CO DETENTION FACILITY'
#  'THE DURHAM CENTER FOR SENIOR LIFE' 'DUKE UNIV. TOWNHOUSE APTS'
#  'ENO TRACE' 'GARRETT FARMS HOA' 'GROVE PARK' 'CHIPOTLE MEXICAN GRILL'
#  'NORTH POINTE COMMONS' 'GSK COMMERCIAL OPERATIONS CENTER'
#  'SCI- TRIANGLE HOUSE I' 'HAPPY CHINA SICHUAN CUISINE'
#  'HOLLOW ROCK RACQUET AND SWIM C' 'RICHARDSON FAMILY CARE HOME PHASE II'
#  'PUPUSERIA & TAQUERIA DC #31' 'TOMO JAPAN'
#  'BRIGHT HORIZONS FAMILY SOLUTIONS' 'WENDY S   #15'
#  'HILTON GARDEN INN SPA' 'DUKE FOOD SERVICES' 'SALADELIA AT ATC'
#  'NEW DESTINATIONS INC SOUTHWOOD' 'FOOD LION LLC  DELI  #1343'
#  'BURGER KING #944' 'BENETIS' 'ALPACA' 'TOWN & COUNTRY # 1' 'BANGKOK 54'
#  'HILTON GARDEN INN CAFE' 'LAQUINTA INN' 'ONLY BURGER' 'PIZZA HUT'
#  'FALLS POINTE AT THE PARK' 'SEASONS AT SOUTHPOINT' 'CHINA KING'
#  'SUSHINARA DBA CONFUSION' 'WILLOWDAILE APTS' 'ENO TRACE HOA'
#  'VALLEY TERRACE APTS' 'CHAPEL TOWER APTS'
#  'CROSSTOWN AT CHAPEL HILL - PH 2' 'DUKE FACULTY CLUB - MAIN'
#  'VILLAGES AT INDEPENDENCE PARK' 'AR-RAZZAQ ISLAMIC CENTER'
#  'THRILLS FROM THE GRILL' 'INDEPENDENCE PARK APTS' 'PALACE INTERNATIONAL'
#  'WOK N GRILL' 'HARRIS TEETER 224 PRODUCE' 'THE DURHAM FAMILY GROUP HOME'
#  'BARNES AND NOBLE   #2631' 'POLLOS CARBONERA CF-28385'
#  'NEW DAY COMMUNITY SERVICES HOUSE  # 1' 'MCDONALDS #368'
#  'DUBOSE HOUSE AND BAR' "TOLEDO'S II MARKET" 'EL RODEO MEXICAN RESTAURANT'
#  'WILSON HOUSE' 'WASHINGTON DUKE INN POOL' 'KOKYU BBQ' 'AMANTE PIZZA'
#  'LOVING ARMS TENDER TOUCH(LATT) AFL HOME' 'LAGOS MEAT MARKET'
#  'HARRIS TEETER 254 PRODUCE' "MOE'S SOUTHWEST GRILL" 'PIZZA INN'
#  'DURHAM EXCHANGE CLUB CAFETERIA' 'DULCE CAFE & ICE CREAM'
#  "LI MING'S GLOBAL MART (CAFE)" 'BREAK OUT, LLC' 'SERENA'
#  'KROGER 366 DELI' 'DHD GROUP HOME' 'FREEDOM HOUSE RECOVERY'
#  "LI MING'S GLOBAL MART (BAKERY)" 'CHINA EXPRESS' 'SEVEN OAKS TOWNHOMES'
#  'EMO VALLEY SA AND R CLUB' 'DOWNING CREEK HOA' 'VILLAS AT CULP ARBOR'
#  'CHINA WOK' "MICHAEL'S PLACE, INC" 'METRO 8' 'MELTING POT'
#  'SOUTHPOINT CROSSING' 'THAI CAFE' 'PRESTIGE FAMILY CARE HOMES, INC'
#  'CORNING LIFE SCIENCES' 'EDINBOROUGH AT THE PARK - PH 2'
#  'SUNSHINE SMILES ACADEMY' 'SPRINGFIELD APTS' 'ALDEN PLACE APTS'
#  'SPEEDWAY' 'EDINBOROUGH AT THE PARK' 'COLONIAL GRAND AT PATTERSON PLACE'
#  'KANKI JAPANESE HOUSE OF STEAKS' "BRUEGGER'S BAKERY" 'PAPA JOHNS'
#  'WAFFLE HOUSE' "ESSER'S COMMISSARY" 'NORTH POINTE APTS'
#  'HILLS AT SOUTHPOINT' 'DUKE FACULTY CLUB - LAP #1' 'COLONY PARK HOA'
#  'BLACK HORSE RUN POOL' 'BAINBRIDGE IN THE PARK APTS' "MOORE'S HOUSE"
#  'BOJANGLES #6' 'LAS PALMAS' 'WELLSPRING CAFE' 'KROGER R 331  SEAFOOD'
#  'FAMILY FARE INC.' 'EL RODEO' 'CHELSEA CAFE' 'MCDONALDS'
#  'HARRIS TEETER 224 MEAT MARKET' 'CHICK-FIL-A RENAISSANCE VILLAG'
#  'BD TECHNOLOGIES (FLIK INTERNATIONAL)' 'BISCUITVILLE  160'
#  'WASHINGTON DUKE HOTEL' 'PAD THAI' 'PINNACLE RIDGE APTS'
#  'LA QUINTA INN FOOD SERV  184' 'COOK OUT  22'
#  'ENHANCEMENT HEALTH CARE INC' 'CHICK-FIL-A EXPRESS'
#  "DURHAM MEN'S HALFWAY HOUSE" 'KOUMI JAPANESE RESTURANT' 'SUSHI LOVE'
#  'FAITH ASSEMBLY CHRISTIAN ACADEMY' 'TARGET MEAT MARKET'
#  'KEYSTONE CROSSING HOA' 'JUMPING JACKS' 'STAYBRIDGE SUITES BREAKFAST BA'
#  'KROGER R 337 DELI' "CHUBBY'S TACOS WOODCROFT" 'NOODLES & COMPANY'
#  'HOMEWOOD SUITES RDU FOOD SERVICE' 'GSK STIEFEL'
#  'ENO VALLEY SCHOOL LUNCHROOM' 'YMCA DOWNTOWN TRAINING'
#  "DON'S ADULT CARE GROUP HOME" 'HILTON GARDEN INN POOL' 'AZALEA PARK APTS'
#  'WOODCROFT SWIM AND TENNIS CLUB' 'LONG MEADOW PARK'
#  'HILLSIDE PARK - POOL' 'TACOS CALY MFU #2' 'DUKE MANOR APTS'
#  'INNESBROOK APTS' "CHILI'S  115" "BJ'S FAMILY CARE HM #1"
#  "HARDEE'S OF WELLON VILLAGE 135" 'ASIAN KITCHEN'
#  'SODEXOL CREE FITNESS - MEN' 'OAK GROVE SAC CLUB'
#  'SPRING VALLEY ELEMENTARY SAC CLUB' 'NAPLES TERRACE' 'FOOD MART  16  THE'
#  'HOMEWOOD SUITES' 'SPICE & CURRY' 'BE ACADEMY' 'CREEKSIDE SUMMER YOUTH'
#  'SALADELIA' "JOSEPH M. BUSHFAN DBA JOE'S BIG DOGS DC #24" "LINA'S CAFE"
#  'HOLIDAY INN EXPRESS' 'WESTGATE CONDO ASSN' 'COURTYARD BY MARRIOTT RTP'
#  'LA VAQUITA' 'KROGER R 337 SEAFOOD' 'DUKE MOTOR LODGE' 'GOLDEN KRUST'
#  'FAYETTEVILLE STREET ELEMTARY' 'CARTER COMMUNITY'
#  'PROMISE, POWER & PROSPERITY' 'LEARN & PLAY' 'SOUTHEAST COMMUNITY CENTER'
#  'STUDENT U - DURHAM ACADEMY' 'KENWOOD DRIVE HOME'
#  'RED ROBIN GOURMET BURGERS' 'RUBY TUESDAYS #2760'
#  'SPRING VALLEY LIVING AT OAK GROVE' 'HEALTHY START ACADEMY'
#  "TOMMY'S MINI MART" 'CARPENTER FLETCHER ROAD GROUP HOME'
#  "DEVIL'S PIZZERIA" 'BABA GHANNOUJ' 'EXTENDED STAY AMERICA #9683'
#  "ROSE'S CASTLE RESIDENTIAL SERVICES, INC"
#  'DEVEREUX RESIDENTIAL SERVICES #1' 'FOREST HILLS PARK' 'LAKEVIEW SCHOOL'
#  'WOODLAKE HOA' 'TAQUERIA LA ESPERANZA DC #2' 'LOUDERMILK PASTRY KITCHEN'
#  'JAMAICA JAMAICA' 'SECURING RESOURCES FOR CONSUMERS, INC.'
#  'NEW VISIONS OF AFRICA' "KING'S SANDWICH SHOP"
#  'SODEXOL CREE FITNESS - WOMEN' 'RADISSON GOVERNORS INN'
#  'CROASDAILE CROSSINGS' 'EMORY WOODS @ RTP' 'COLONIAL APTS' 'CRICKET INN'
#  'LONE STAR STEAKHOUSE & SALOON' 'COLONIAL GRANDE AT ARRINGTON A'
#  'MEDICAL PARK INN' 'HOPE VALLEY FARMS SWIM AND RAC' 'RESIDENCE INN'
#  'SUMMIT SQUARE APTS' 'ANGELICA HOUSES FAMILY CARE HOME'
#  'MELBOURNE STREET GROUP HOME' 'CAMPUS CROSSINGS APTS'
#  'HOPE VALLEY CC WADING' 'ROYAL OAKS APTS' 'THE HAMPTONS AT RESEARCH PK'
#  'COLONIAL GRAND AT RESEARCH PAR' 'CEDARS OF CHAPEL HILL POOL'
#  'GREENS OF PINE GLEN' 'YMCA DOWNTOWN LAP POOL' 'BERKELEY AT SOUTHPOINT'
#  'COMFORT SUITES HOTEL OY POOL' 'COURTYARD BY MARRIOTT' 'OVAL PARK GRILLE'
#  'MAC-UR-RONI' 'ZINBURGER' 'A NEW BEGINNING'
#  'TRINITY COMMONS OUTDOOR POOL' 'BEER DURHAM' "MAX'S PLACE AT ARNETTE"
#  'DUNKIN DONUTS BASKIN ROBBINS' 'HUNGRY LEAF'
#  'RECOVERY CONNECTIONS OF DURHAM II' "DOMINO'S"
#  "LI MING'S GLOBAL MART (MEAT MARKET)" 'HEIGHTS AT SOUTH LASALLE'
#  'BULL STREETGOURMET AND MARKET' 'ZION FAMILY CARE HOME'
#  'ELSIE-DORIS FAMILY CARE HOME' 'CIRCLE OF DAUGHTERS'
#  'PRUITT HEALTH DURHAM IFS' 'SPRING VALLEY ELEMENTARY SCHOOL'
#  'TLC ADULT GROUP HOME' 'CARE HEALTH SERVICES I'
#  'CHANGING LIVES RESIDENTIAL CARE' 'JONES FAMILY HOME' 'CIRCLE K  6330'
#  'BURTON ELEMENTARY SCHOOL PRE K' 'BEECH LAKE APARTMENTS' 'CAMP CALVARY'
#  'SOUTHPOINT VILLAGE WADING POOL' 'LITTLE PEOPLE DAY CARE'
#  'CHANGING PLACES' 'SANDY RIDGE ELEM. SCHOOL'
#  'CAMP DISCOVER II FOREST HILLS' 'W G PEARSON ELEMENTARY COMMUNITY ED.'
#  'SPRING VALLEY ELEMTARY' 'YMCA DOWNTOWN' "KING'S DAUGHTERS INN"
#  'ALL MY CHILDREN CHILDCARE CENTER' 'GUCKENHEIMER  AT AICPA'
#  'EINSTEIN BROTHERS BAGEL' 'NEW BEGINNINGS' 'VICTORY RESIDENTIAL SERVICES'
#  'CENTRAL FAMILY CARE HOME' 'BUY QUICK FOOD MART' 'STARBUCKS'
#  'PICKETT GROVE SUPERVISED LIVING' 'BEGIN AGAIN FAMILY CARE HOME #2'
#  'SCI TRIANGLE HOUSE II' 'ROCHELLE MANOR' 'LYON PARK'
#  'MT CALVARY LIGHTHOUSE' 'EASTWOOD CHC #2' 'HOPE VALLEY COMMUNITY'
#  'ROSHAUNS HOUSE OF CARE' 'WESTGLEN ROAD GROUP HOME' 'STUDIO PLUS'
#  'WYNDCROSSE' 'YOUTH LIFE FOUNDATION' 'GLOBAL SCHOLAR ACADEMY'
#  'GREAT BEND GROUP HOME' 'SUPREME FAMILY CARE HOME LLC'
#  'HOMEWOOD SUITES RDU' 'ULTIMATE FAMILY CARE HOME'
#  'COORDEGY INC ( D/B/A RALEIGH EVENT CATERING)' 'SPRING VALLEY LIVING'
#  'TROPICAL DELIGHT DC #74' 'MT VERNON BAPTIST CHURCH' 'DAMAR COURT UNIT'
#  'PARKWOOD METHODIST CHURCH' "CJ'S STREET FOOD DC# 130" 'CORNWALLIS DHA'
#  'THE DURHAM FAMILY GROUP HOME WILKERSON AVENUE HOUS'
#  'OXFORD MANOR HEADSTART' 'FOREST GLEN APTS' 'FOXRIDGE APTS'
#  'LUCAS MIDDLE SCHOOL' 'LIBERTY ST. REC CENTER' 'FAITH COMMUNITY'
#  'HILLSIDE HIGH SCHOOL ACADEMY' 'TRAINING FOR SUCCESS' 'CORE'
#  'SUCCESS MARTIAL ARTS' 'MORRENE ROAD' 'CAMP SUCCESS' 'HAPPY KIDS'
#  'EL CENTRO HISPANO' 'CAMP EXPLORE LYON PARK']
# delete_mark: ['ACTIVE' 'DELETED']
# travel_time_min: [ 0. nan]
# biguanide_sum: [nan 0.  7.3]
# action_code_desc: [nan]
# travel_time_hrs: [ 0. nan]
# water_temp_sum: [  nan 100.  104.   87.  102.   74.   84.   83.   87.2  78.8 103.   82.
#   86.   79.   84.5  85.   88.2 101.5  85.4  83.5 106.   82.3 102.5  81.
#  104.9  96.   78.  102.3  92.   84.3 103.8  89.2  90.  101.4  81.5 101.
#    0.   70.   80.7 105.5  87.3  89.9  86.6 105.  103.5 109.   83.3 107.
#  102.9  80.   88.   95.   85.8 103.6  86.5  99.2  88.5  87.6 103.1  89.
#   99.   91.   86.9  83.6 103.4 106.5  87.5  93.   89.5  80.5  98.   94.
#   88.7  80.4  85.5  75.   73.   88.8  83.9  83.2  85.7 101.8  85.3  83.7
#   84.2 100.5  86.3 100.7  86.4  82.8 102.1  88.3  83.4  98.4  75.3  87.9
#  103.2  77.  106.8  77.5  88.6  88.1 300.  103.9 105.9  89.4  98.3  99.7
#   93.7  72.   80.9  82.5  82.1  82.9  89.7 102.8  99.1  87.4 101.3  87.8
#   94.4  82.7  62.    7.  101.9  69.5  85.6 104.7 102.4  65. ]
# epi_type_id: [nan  1.]
# sewage: [1 3 4 2]
# ehs_num: [nan]
# classification_id: [nan  3.  1.  5.  6.  2.  4.  7.]
# insp_type: [ 1 12  2  5  6  9 10  8 13 31 32]
# type_description: ['1 - INSPECTION' 'S - STATUS CHANGE' '2 - RE-INSPECTION' 'P - PERMIT'
#  'V - VISIT' 'VERIFICATION' 'OTHER' 'NAME CHANGE' 'PRE-OPENING VISIT'
#  'CVV - CRITICAL VIOLATION VISIT' 'CVF - CRITICAL VIOLATION FOLLOWUP']
# field59: [nan]
# time_of_inspection_hr: [nan  9.  1. 12.  2. 10. 11.  7.  3.  8.  4.  6.  5.  0.]
# insp_date: ['2002-05-17' '2003-05-28' '2003-10-14' ... '2013-12-21' '2014-01-18'
#  '2013-04-21']
# num_repeat_rf_inter_viol: [nan  0.  1.  3.  2.  4.  7.  5.  6.  8.]
# est_type_num: [nan]
# est_type: [ 1 40 41 42 11 14 16 20 30 21 22 23 50  3 53 51 44  2  4 61 72 43 73  6
#  55 52 47  5  9 45 48 15 54 12 49]
# rpt_area_num: [nan]
# action_code_id: [nan]
# permit_type_id: [nan]
# complaint_section: [nan]
# water: [1 5 6 3 4 2]
# rpt_area_code: [605 645 660 620 622 650 621 802 602 637 634 607 655 646 649]
# person_incharge_fname: [nan 'Patrick' '•oliver' ... 'carl' 'CIRIO' 'MARQUIS']
# est_id: [ 56537  56538  56539 ... 122015 122017 122044]
# water_ph_sum: [ nan  7.6  7.5  7.3  7.8  7.2  7.4  7.7  7.   6.8  8.2  0.   8.1  4.6
#   6.2  1.5  8.   1.6  0.6  6.6  7.1  0.1  0.7  7.9  6.9  9.8  1.3  1.
#   6.  17.3 78.8  3.4  3.3  9.   3.1  8.4  1.4  2.5  9.5  1.8  3.2]
# end_time_of_inspection_hh: [nan 10.  1. 12.  4.  2. 11.  8.  3.  5.  9.  7.  6.  0. 13. 16. 17. 22.]
# inspection_time_min: [  0.  15.  30.   5.   3.  45.  20.  35.  47.  10.  44.  nan   8.  25.
#   51.   2.  50.   4.  40.  55.   6.  41.  18.  57.  16.  11.  17.   1.
#   22.  14.  38.  48.  43.  29.  33.  32.  52.  59.  26.   7.  12.  37.
#   23.  39.  56.  27.  13.   9.  58.  31.  36.  21.  24.  34.  28.  19.
#   53.  42.  49.  46. -53.  54. -30.  -2. -58.  -5. -50. -45. -15. -25.
#   -8.  -1.  -7. -21. -38.  -9. -47. -43. -40. -41. -16.  -6. -56. -51.
#  -10. -55. -29. -37. -39. -32.]
# num_rf_inter_viol: [nan  0.  3.  6.  5.  2.  4.  1.  7.  8.  9. 13. 11. 10.]
# extra_credit: ['N' 'Y']
# origin: [5 1]
# geolocation: [nan "{'lat': 36.0291871, 'lon': -78.913978}"
#  "{'lat': 35.9713262, 'lon': -78.9467524}"
#  "{'lat': 36.0191742, 'lon': -78.9470248}"
#  "{'lat': 35.925738, 'lon': -78.953569}"
#  "{'lat': 36.0553803, 'lon': -78.9033564}"
#  "{'lat': 35.908347, 'lon': -78.9848706}"
#  "{'lat': 35.9824671, 'lon': -78.8295962}"
#  "{'lat': 35.95076, 'lon': -78.906744}"
#  "{'lat': 36.0081147, 'lon': -78.933279}"
#  "{'lat': 36.0102648, 'lon': -78.9183749}"
#  "{'lat': 36.0490059, 'lon': -78.898257}"
#  "{'lat': 35.966712, 'lon': -78.906659}"
#  "{'lat': 35.994129, 'lon': -78.87834}"
#  "{'lat': 35.930153, 'lon': -78.86674}"
#  "{'lat': 36.0440464, 'lon': -78.8152888}"
#  "{'lat': 35.9998819, 'lon': -78.910101}"
#  "{'lat': 36.0070978, 'lon': -78.9371233}"
#  "{'lat': 35.9083719, 'lon': -78.9851445}"
#  "{'lat': 35.890374, 'lon': -78.886049}"
#  "{'lat': 35.8968942, 'lon': -78.9394702}"
#  "{'lat': 35.9898862, 'lon': -78.8567627}"
#  "{'lat': 35.9207272, 'lon': -78.9573299}"
#  "{'lat': 36.0143674, 'lon': -78.9340232}"
#  "{'lat': 36.0563119, 'lon': -78.9033258}"
#  "{'lat': 35.9879403, 'lon': -78.8879702}"
#  "{'lat': 35.9742205, 'lon': -78.7930157}"
#  "{'lat': 35.9026718, 'lon': -78.956667}"
#  "{'lat': 35.9205016, 'lon': -78.8108783}"
#  "{'lat': 36.0165379, 'lon': -78.8849457}"
#  "{'lat': 36.041862, 'lon': -78.8935925}"
#  "{'lat': 35.9737738, 'lon': -78.9483332}"
#  "{'lat': 36.00433, 'lon': -78.919329}"
#  "{'lat': 36.0052163, 'lon': -78.9215119}"
#  "{'lat': 35.9316295, 'lon': -78.9082959}"
#  "{'lat': 36.065495, 'lon': -78.943225}"
#  "{'lat': 35.971894, 'lon': -78.95754289999999}"
#  "{'lat': 35.8798244, 'lon': -78.8446277}"
#  "{'lat': 35.9973818, 'lon': -78.901896}"
#  "{'lat': 35.9018632, 'lon': -78.9005119}"
#  "{'lat': 36.02501, 'lon': -78.956104}"
#  "{'lat': 36.0208896, 'lon': -78.9477182}"
#  "{'lat': 35.9080658, 'lon': -78.8912723}"
#  "{'lat': 35.9109591, 'lon': -78.8928888}"
#  "{'lat': 35.9557878, 'lon': -78.883536}"
#  "{'lat': 36.1218465, 'lon': -78.9198633}"
#  "{'lat': 36.015767, 'lon': -78.9189648}"
#  "{'lat': 35.8806773, 'lon': -78.8494375}"
#  "{'lat': 35.9174972, 'lon': -78.9583786}"
#  "{'lat': 35.976154, 'lon': -78.892677}"
#  "{'lat': 35.954664, 'lon': -78.995079}"
#  "{'lat': 35.9825874, 'lon': -78.8779264}"
#  "{'lat': 35.999829, 'lon': -78.836437}"
#  "{'lat': 36.016667, 'lon': -78.889622}"
#  "{'lat': 35.9103688, 'lon': -79.0048429}"
#  "{'lat': 35.910106, 'lon': -78.986231}"
#  "{'lat': 36.0495727, 'lon': -78.9046188}"
#  "{'lat': 35.9864014, 'lon': -78.9240294}"
#  "{'lat': 35.898608, 'lon': -78.894478}"
#  "{'lat': 35.9093505, 'lon': -78.9865836}"
#  "{'lat': 35.987108, 'lon': -78.923927}"
#  "{'lat': 36.0202618, 'lon': -78.9470788}"
#  "{'lat': 36.0563065, 'lon': -78.930937}"
#  "{'lat': 35.9521523, 'lon': -78.9930656}"
#  "{'lat': 36.0534521, 'lon': -78.9038821}"
#  "{'lat': 35.975221, 'lon': -78.8777768}"
#  "{'lat': 35.9206841, 'lon': -78.9296421}"
#  "{'lat': 35.9658692, 'lon': -78.9633656}"
#  "{'lat': 36.041469, 'lon': -78.878339}"
#  "{'lat': 36.0297837, 'lon': -78.9204786}"
#  "{'lat': 36.012955, 'lon': -78.880095}"
#  "{'lat': 35.9955541, 'lon': -78.8919894}"
#  "{'lat': 35.9014906, 'lon': -78.8915172}"
#  "{'lat': 36.0686297, 'lon': -78.9046042}"
#  "{'lat': 36.0743655, 'lon': -78.9002068}"
#  "{'lat': 35.89268, 'lon': -78.9134629}"
#  "{'lat': 35.925015, 'lon': -78.990694}"
#  "{'lat': 36.026722, 'lon': -78.8860152}"
#  "{'lat': 36.0093112, 'lon': -78.9217794}"
#  "{'lat': 35.9015132, 'lon': -78.9396844}"
#  "{'lat': 35.9120185, 'lon': -78.9391092}"
#  "{'lat': 35.9744835, 'lon': -78.9241271}"
#  "{'lat': 36.0372345, 'lon': -78.8730993}"
#  "{'lat': 36.0962, 'lon': -78.8521943}"
#  "{'lat': 35.8937048, 'lon': -78.8466296}"
#  "{'lat': 36.035392, 'lon': -78.911113}"
#  "{'lat': 35.9581825, 'lon': -78.968559}"
#  "{'lat': 35.963248, 'lon': -78.967652}"
#  "{'lat': 35.9560013, 'lon': -78.8418243}"
#  "{'lat': 35.9531739, 'lon': -78.9852335}"
#  "{'lat': 35.9527729, 'lon': -78.9945244}"
#  "{'lat': 35.9550003, 'lon': -78.9931015}"
#  "{'lat': 36.0211364, 'lon': -78.9505031}"
#  "{'lat': 35.9708359, 'lon': -78.8668419}"
#  "{'lat': 35.9027347, 'lon': -78.8943634}"
#  "{'lat': 35.884681, 'lon': -78.945198}"
#  "{'lat': 35.980179, 'lon': -78.96408}"
#  "{'lat': 36.1773735, 'lon': -78.9020236}"
#  "{'lat': 35.9382025, 'lon': -78.8973604}"
#  "{'lat': 36.0373702, 'lon': -78.8708472}"
#  "{'lat': 36.0583372, 'lon': -78.9032023}"
#  "{'lat': 35.9815164, 'lon': -78.8201474}"
#  "{'lat': 36.0070981, 'lon': -78.9207011}"
#  "{'lat': 35.9125482, 'lon': -78.9363925}"
#  "{'lat': 35.9115178, 'lon': -78.9835277}"
#  "{'lat': 35.9658593, 'lon': -78.960942}"
#  "{'lat': 35.8787835, 'lon': -78.8456172}"
#  "{'lat': 35.9110201, 'lon': -78.9374674}"
#  "{'lat': 35.9022771, 'lon': -78.957548}"
#  "{'lat': 35.8919782, 'lon': -78.8587915}"
#  "{'lat': 36.0176021, 'lon': -78.942742}"
#  "{'lat': 36.0266083, 'lon': -78.9228698}"
#  "{'lat': 35.9652997, 'lon': -78.9488454}"
#  "{'lat': 36.0232472, 'lon': -78.9547992}"
#  "{'lat': 36.0127611, 'lon': -78.9135753}"
#  "{'lat': 35.994819, 'lon': -78.89106}"
#  "{'lat': 36.0069674, 'lon': -78.946862}"
#  "{'lat': 35.9629837, 'lon': -78.9094238}"
#  "{'lat': 35.970283, 'lon': -78.9540086}"
#  "{'lat': 35.8713128, 'lon': -78.8560766}"
#  "{'lat': 36.039555, 'lon': -78.930151}"
#  "{'lat': 35.9488226, 'lon': -78.9952256}"
#  "{'lat': 35.8869458, 'lon': -78.8486741}"
#  "{'lat': 35.9213919, 'lon': -78.958298}"
#  "{'lat': 35.9236744, 'lon': -78.8754842}"
#  "{'lat': 35.9882332, 'lon': -78.9000237}"
#  "{'lat': 36.0851774, 'lon': -78.912153}"
#  "{'lat': 35.9981189, 'lon': -78.9006895}"
#  "{'lat': 35.9650476, 'lon': -78.894792}"
#  "{'lat': 36.045277, 'lon': -78.932896}"
#  "{'lat': 35.920859, 'lon': -78.950483}"
#  "{'lat': 35.9934258, 'lon': -78.8846448}"
#  "{'lat': 35.9822207, 'lon': -78.9016503}"
#  "{'lat': 36.014878, 'lon': -78.9465644}"
#  "{'lat': 35.9618939, 'lon': -78.9779035}"
#  "{'lat': 36.025996, 'lon': -78.880642}"
#  "{'lat': 35.9631504, 'lon': -78.8455484}"
#  "{'lat': 35.9191846, 'lon': -78.9596634}"
#  "{'lat': 36.003221, 'lon': -78.865447}"
#  "{'lat': 35.9126874, 'lon': -78.8916603}"
#  "{'lat': 35.9497355, 'lon': -78.9955234}"
#  "{'lat': 35.9023528, 'lon': -78.8948715}"
#  "{'lat': 35.9821204, 'lon': -78.9315981}"
#  "{'lat': 36.0093105, 'lon': -78.9417128}"
#  "{'lat': 36.0275026, 'lon': -78.9239574}"
#  "{'lat': 35.9617239, 'lon': -78.9640358}"
#  "{'lat': 35.9047256, 'lon': -78.8958006}"
#  "{'lat': 36.0182097, 'lon': -78.9467118}"
#  "{'lat': 35.9698235, 'lon': -78.9611158}"
#  "{'lat': 35.9644701, 'lon': -78.9055786}"
#  "{'lat': 36.016338, 'lon': -78.913897}"
#  "{'lat': 35.9413196, 'lon': -78.9020213}"
#  "{'lat': 35.934225, 'lon': -78.907484}"
#  "{'lat': 36.084289, 'lon': -78.886403}"
#  "{'lat': 35.9533167, 'lon': -78.9968077}"
#  "{'lat': 36.0166595, 'lon': -78.8890399}"
#  "{'lat': 35.9814075, 'lon': -78.8193962}"
#  "{'lat': 35.996476799999996, 'lon': -78.9136889}"
#  "{'lat': 35.9450873, 'lon': -78.8377128}"
#  "{'lat': 35.916007, 'lon': -78.901524}"
#  "{'lat': 36.0092039, 'lon': -78.9219025}"
#  "{'lat': 35.960063, 'lon': -78.961433}"
#  "{'lat': 35.950637, 'lon': -78.910749}"
#  "{'lat': 36.000055, 'lon': -78.835434}"
#  "{'lat': 35.98105, 'lon': -78.912209}"
#  "{'lat': 36.0374439, 'lon': -78.878222}"
#  "{'lat': 35.9214667, 'lon': -78.9247949}"
#  "{'lat': 35.9944665, 'lon': -78.8819836}"
#  "{'lat': 35.9033017, 'lon': -78.8935214}"
#  "{'lat': 35.9599168, 'lon': -78.8820312}"
#  "{'lat': 35.9808865, 'lon': -78.8996232}"
#  "{'lat': 36.0039334, 'lon': -78.9016167}"
#  "{'lat': 35.8951226, 'lon': -78.864704}"
#  "{'lat': 36.0359911, 'lon': -78.9387615}"
#  "{'lat': 35.9390655, 'lon': -78.8957234}"
#  "{'lat': 35.9706393, 'lon': -78.9407908}"
#  "{'lat': 36.0296779, 'lon': -78.9371908}"
#  "{'lat': 35.8805744, 'lon': -78.8285232}"
#  "{'lat': 35.934, 'lon': -78.938488}"
#  "{'lat': 35.9041757, 'lon': -78.8974251}"
#  "{'lat': 35.9603723, 'lon': -78.9655895}"
#  "{'lat': 36.045173, 'lon': -78.918719}"
#  "{'lat': 35.993491, 'lon': -78.853173}"
#  "{'lat': 35.9431082, 'lon': -78.9030057}"
#  "{'lat': 35.9480977, 'lon': -78.9472707}"
#  "{'lat': 35.9672073, 'lon': -78.9492826}"
#  "{'lat': 35.9409894, 'lon': -78.8632172}"
#  "{'lat': 35.9067074, 'lon': -79.0057432}"
#  "{'lat': 35.907862, 'lon': -78.920936}"
#  "{'lat': 35.9985039, 'lon': -78.9010921}"
#  "{'lat': 35.9134746, 'lon': -78.9310236}"
#  "{'lat': 35.8799558, 'lon': -78.8436546}"
#  "{'lat': 36.0165031, 'lon': -78.9188891}"
#  "{'lat': 35.968657, 'lon': -78.953113}"
#  "{'lat': 35.9662633, 'lon': -78.9518334}"
#  "{'lat': 36.00039, 'lon': -78.903111}"
#  "{'lat': 35.998479, 'lon': -78.8994984}"
#  "{'lat': 35.989074, 'lon': -78.914674}"
#  "{'lat': 35.9601366, 'lon': -78.9221342}"
#  "{'lat': 36.0023114, 'lon': -78.9133683}"
#  "{'lat': 36.011922, 'lon': -78.950128}"
#  "{'lat': 35.9939636, 'lon': -78.8687085}"
#  "{'lat': 36.026804, 'lon': -78.825049}"
#  "{'lat': 35.9881793, 'lon': -78.8791733}"
#  "{'lat': 35.943513, 'lon': -78.8862975}"
#  "{'lat': 36.0043053, 'lon': -78.9508168}"
#  "{'lat': 35.9783311, 'lon': -78.9024144}"
#  "{'lat': 36.025338, 'lon': -78.886949}"
#  "{'lat': 36.050937, 'lon': -78.917332}"
#  "{'lat': 36.01133, 'lon': -78.862038}"
#  "{'lat': 35.933241, 'lon': -78.888771}"
#  "{'lat': 35.9550718, 'lon': -78.9689036}"
#  "{'lat': 35.9893979, 'lon': -78.9197121}"
#  "{'lat': 35.8993334, 'lon': -78.9387728}"
#  "{'lat': 35.9926826, 'lon': -78.8691702}"
#  "{'lat': 35.939672, 'lon': -78.911748}"
#  "{'lat': 36.0569913, 'lon': -78.8697388}"
#  "{'lat': 35.9582719, 'lon': -78.9074315}"
#  "{'lat': 36.0081136, 'lon': -78.9224399}"
#  "{'lat': 36.0037149, 'lon': -78.9120458}"
#  "{'lat': 35.9701993, 'lon': -78.9426613}"
#  "{'lat': 35.9167901, 'lon': -78.9825369}"
#  "{'lat': 36.0091222, 'lon': -78.9360286}"
#  "{'lat': 35.958269, 'lon': -78.892244}"
#  "{'lat': 36.03624, 'lon': -78.8691374}"
#  "{'lat': 36.0510295, 'lon': -78.9719922}"
#  "{'lat': 35.9811503, 'lon': -78.8747011}"
#  "{'lat': 36.0117338, 'lon': -78.9363491}"
#  "{'lat': 35.975004, 'lon': -78.988448}"
#  "{'lat': 35.9893234, 'lon': -78.8821092}"
#  "{'lat': 35.9500033, 'lon': -78.8418604}"
#  "{'lat': 35.9905166, 'lon': -78.8484735}"
#  "{'lat': 35.9906172, 'lon': -78.878159}"
#  "{'lat': 35.9296993, 'lon': -78.9108436}"
#  "{'lat': 35.9670939, 'lon': -78.9398339}"
#  "{'lat': 36.06594, 'lon': -78.932167}"
#  "{'lat': 35.976382, 'lon': -78.972273}"
#  "{'lat': 35.9049734, 'lon': -78.9327858}"
#  "{'lat': 35.9659999, 'lon': -78.917127}"
#  "{'lat': 36.0003336, 'lon': -78.8929846}"
#  "{'lat': 36.0210123, 'lon': -78.847151}"
#  "{'lat': 36.002612, 'lon': -78.867858}"
#  "{'lat': 36.066541, 'lon': -78.903012}"
#  "{'lat': 35.9839222, 'lon': -78.9247565}"
#  "{'lat': 36.0237073, 'lon': -78.95042}"
#  "{'lat': 35.9839402, 'lon': -78.9023889}"
#  "{'lat': 36.0060658, 'lon': -78.9532359}"
#  "{'lat': 35.8944097, 'lon': -78.9092955}"
#  "{'lat': 35.9966873, 'lon': -78.9210582}"
#  "{'lat': 35.9634176, 'lon': -78.9146655}"
#  "{'lat': 35.9992967, 'lon': -78.9173606}"
#  "{'lat': 36.0403831, 'lon': -78.8857515}"
#  "{'lat': 35.9367081, 'lon': -78.9001796}"
#  "{'lat': 35.9304056, 'lon': -78.8134331}"
#  "{'lat': 36.109108, 'lon': -78.886559}"
#  "{'lat': 35.991559, 'lon': -78.8928697}"
#  "{'lat': 36.065366, 'lon': -78.90693}"
#  "{'lat': 36.0022654, 'lon': -78.908876}"
#  "{'lat': 35.9846415, 'lon': -78.834742}"
#  "{'lat': 36.0071709, 'lon': -78.9554813}"
#  "{'lat': 35.93571, 'lon': -78.888659}"
#  "{'lat': 35.982492, 'lon': -78.8213398}"
#  "{'lat': 35.9957801, 'lon': -78.9020007}"]
# grade: ['A' nan 'B' 'C']
# est_group_desc: [nan 'Full-Service Restaurant' 'Meat and Poultry Department'
#  'Fast Food Restaurant' 'Hospital' 'Nursing Home' 'Elementary School'
#  'Deli Department' 'Produce Department and Salad Bar' 'Seafood Department']
# oss_id: [nan]
# county: [32]
# verification_required_date: [nan '10-JUN-2014' '16-JUN-2014' '18-JUN-2014' '23-JUN-2014' '27-JUN-2014'
#  '09-JUL-2014' '12-JUL-2014' '13-JUL-2014' '07-JUL-2014' '22-JUL-2014'
#  '21-JUL-2014' '16-JUL-2014' '15-JUL-2014' '23-JUL-2014' '20-MAY-2014'
#  '26-MAY-2014' '28-MAY-2014' '14-AUG-2013' '23-AUG-2013' '29-AUG-2013'
#  '05-SEP-2013' '10-SEP-2013' '11-SEP-2013' '18-SEP-2013' '23-SEP-2013'
#  '25-SEP-2013' '26-SEP-2013' '09-OCT-2013' '22-OCT-2013' '24-OCT-2013'
#  '28-OCT-2013' '06-NOV-2013' '13-JAN-2014' '02-JAN-2014' '14-JAN-2014'
#  '28-JAN-2014' '24-JUN-2013' '25-JUN-2013' '26-JUL-2013' '23-JUL-2013'
#  '06-AUG-2013' '01-AUG-2013' '21-MAR-2014' '11-MAR-2014' '18-MAR-2014'
#  '04-APR-2014' '09-AUG-2013' '13-AUG-2013' '25-NOV-2013' '29-NOV-2012'
#  '04-JAN-2013' '02-JAN-2013' '18-SEP-2012' '24-SEP-2012' '27-SEP-2012'
#  '11-OCT-2012' '08-OCT-2012' '22-OCT-2012' '25-OCT-2012' '06-SEP-2012'
#  '03-APR-2013' '28-MAY-2013' '08-DEC-2016' '17-FEB-2017' '27-AUG-2016'
#  '05-SEP-2016' '01-SEP-2016' '15-SEP-2016' '19-SEP-2016' '03-OCT-2016'
#  '06-OCT-2016' '22-OCT-2016' '23-OCT-2016' '14-NOV-2016' '26-APR-2016'
#  '08-MAY-2016' '17-MAY-2016' '27-MAY-2016' '25-MAY-2016' '10-JUN-2016'
#  '24-JUN-2016' '03-JUL-2016' '13-JUL-2016' '21-JUL-2016' '30-JUL-2016'
#  '09-OCT-2015' '10-OCT-2015' '16-OCT-2015' '23-OCT-2015' '03-NOV-2015'
#  '06-NOV-2015' '11-NOV-2015' '26-NOV-2015' '08-DEC-2015' '14-DEC-2015'
#  '24-DEC-2015' '27-DEC-2015' '16-JAN-2016' '06-JUL-2015' '24-JUL-2015'
#  '30-JUL-2015' '31-JUL-2015' '07-AUG-2015' '05-AUG-2015' '04-AUG-2015'
#  '14-AUG-2015' '16-MAR-2016' '24-MAR-2016' '07-APR-2016' '23-SEP-2015'
#  '30-SEP-2015' '06-OCT-2015' '07-OCT-2015' '18-AUG-2015' '27-AUG-2015'
#  '20-AUG-2015' '03-SEP-2015' '06-FEB-2016' '19-FEB-2016' '15-MAY-2015'
#  '22-MAY-2015' '21-MAY-2015' '17-JUN-2015' '24-JUN-2015' '23-JUN-2015'
#  '27-JUN-2015' '25-JUN-2015' '01-JUL-2015' '14-NOV-2014' '20-NOV-2014'

#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2014-12-Dec'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2014-12-Dec\\'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-01-Jan'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-01-Jan\\'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-02-Feb'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-02-Feb\\'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-03-Mar\\'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-03-Mar'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2014-09-Sep'
#  '\\\\kymo02\\MicoForms\\NCENV\\2014-09-Sep'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2014-08-Aug'
#  '\\\\kymo02\\MicoForms\\NCENV\\2014-08-Aug'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-04-Apr\\'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2015-04-Apr'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2014-10-Oct\\'
#  '\\\\kymo02\\MicoForms\\NCENV\\2011-04-Apr'
#  '\\\\Kymo02\\MICOFORMS\\NCENV\\2017-02-Feb']
# ehs_id: [ 484  892  465  602  474  479  883  911  515  467  478  687  480  930
#   475  700  658  472  940  471  572  910  473  481  477  483  482  476
#  1024 1119 1085 1166 1200 1108 1025 1048  891  464 1208  239  466]
# six_point_demerit: ['N' 'Y']
# group_code_id: [ 1. nan  0.]
# request_number: [nan]
# state_id: [4032011124 4032011125 4032011126 ... 4032720132 4032720174 4032720177]
# smoking_allowed: [nan 'N' 'Y']
# classification_desc: [nan 'Provisional' 'Superior' 'Approved' 'Disapproved']
# permit_status: [nan]
# sample_attendance: [nan]
# sample: ['N' 'Y']
# comment_sheet_id: ['NO' 'YES']
# sent_to_bets_yn: ['YES' 'NO']
# id: [ 905658  905662  905664 ... 1818093 1818100 1818270]
# violations_id: [0]
# inspection_time_hrs: [  0.   1.   2.  nan   4.   3.   6.  14.  12. -11. -10.  13.  -1.  -8.
#   -7.  -9. -12.  11.  23.   5. -15. -14.   7.   9. -13.  -3.  -2.  -6.
#   10.  21.  -5.]
# setup_date: ['2008-05-22' '2014-06-03' '2014-06-04' ... '2016-01-30' '2016-10-15'
#  '2013-07-19']
# time_of_inspection_mm: [nan 30.  0. 45. 15. 59. 20. 54. 33. 40. 35. 14. 25. 50.  5.  7.  1.  6.
#  57. 10. 29. 52. 13. 28.  9. 51. 34. 55. 24. 32.  3. 46.  2. 17. 16.  4.
#  23. 43.  8. 48. 18. 42. 19. 36. 58. 22. 37. 41. 39. 12. 27. 26. 21. 11.
#  31. 44. 47. 53. 38. 56. 49.]
# mileage: [nan]
# permit_status_id: [ 1.  8. 13.  9.  3. 15. 11. 17.  4. 10.  5. 16.  2. 19. 18.  7. 14.  6.
#  nan]
# ampm_of_inspection: [nan 'AM' 'PM']
# followup_id: ['NO']
# rpt_area_desc: ['Food Service' 'Institutions' 'Day Care' 'Lodging' 'Bed&Breakfast Home'
#  'Summer Camps' 'Bed&Breakfast Inn' 'Swimming Pools' 'Mobile Food'
#  'School Buildings' 'Tattoo Establishments' 'Summer Food'
#  'Residential Care' 'Local Confinement' 'Adult Day Care']
# time_of_inspection: [      nan 9.300e+02 2.450e+02 1.015e+03 2.300e+02 9.000e+02 1.100e+03
#  7.590e+02 3.000e+02 1.150e+02 1.000e+02 3.300e+02 2.000e+02 1.030e+03
#  8.540e+02 9.330e+02 9.150e+02 1.140e+03 9.350e+02 1.214e+03 9.400e+02
#  1.130e+03 4.000e+02 2.150e+02 1.250e+02 1.500e+02 1.050e+02 1.045e+03
#  5.190e+02 7.040e+02 5.120e+02]
# chlorine_sum: [ nan  4.   2.   8.   3.   5.  10.   2.5  7.   1.5  0.1  6.   0.5  1.
#   4.5  7.5  3.5  0.  20.   1.8  3.7  2.6  3.8 19.   5.7  4.4  5.6  7.6
#  10.7  5.5  2.8  1.7  0.8  3.9  5.9  4.7  4.6  2.9  8.5 10.9 30. ]
# bromine_sum: [ nan 12.5  4.5  9.   7.   0.   8.   3.   5.   2.   4.   6.  10.   6.8
#   1.  20.  25.   2.3  0.1  2.2  3.3  0.4]
# est_group_id: [nan  5.  7.  4.  1.  2.  3.  6.  8.  9.]
# inspection_reason_desc: [nan 'Status Change' 'Name Change' 'Visit' 'Other' 'Verification']

# %%
# Separate out longitudes and latitudes from geolocation column

# Convert 'geolocation column to string type
scores_df = scores_df.astype({'geolocation': str})

# Split the geolocation string into two parts in geo_list
scores_df['geo_list'] = [row.split(',') for row in scores_df['geolocation']]

# Enter the first element from the list in each row of geo_list in the new column, lat
scores_df['lat'] = [row[0] for row in scores_df['geo_list']]

# Remove characters that are not numerical, '.', or '-' from lat
scores_df['lat'] = [re.sub("[^0-9,.,-]","",string) for string in scores_df.lat]

# Enter the last element from the list in each row of geo_list in the new column, lon
scores_df['lon'] = [row[-1] for row in scores_df['geo_list']]

# Remove characters that are not numerical, '.', or '-' from lon
scores_df['lon'] = [re.sub("[^0-9,.,-]","",string) for string in scores_df.lon]

# %% [markdown]
# Despite the score_sum and grade columns contain missing values (13 % and 51%, respectively), we will leave both because those are the target features for the analysis. We will check if we can fill in more grades based on the score_sum value.

# %% [markdown]
# We will min and max values of scores in grades A, B, and C to guide assignments of scores that do not have grades.

# %%
# Plot the box plot of scores by grade.
sns.boxplot(x = 'score_sum', y = 'grade', data = scores_df)
# Out:
# <Axes: xlabel='score_sum', ylabel='grade'>

# %%
# Calculate the min and max score by grade letters
scoresdf_A = scores_df[scores_df['grade'] == 'A']
scoresdf_B = scores_df[scores_df['grade'] == 'B']
scoresdf_C = scores_df[scores_df['grade'] == 'C']

print('Min A: ' + str(scoresdf_A['score_sum'].min()),'Max A: ' + str(scoresdf_A['score_sum'].max()))
print('Min B: ' + str(scoresdf_B['score_sum'].min()),'Max B: ' + str(scoresdf_B['score_sum'].max()))
print('Min C: ' + str(scoresdf_C['score_sum'].min()),'Max C: ' + str(scoresdf_C['score_sum'].max()))
# Out:
# Min A: 88.0 Max A: 100.0
# Min B: 79.0 Max B: 89.0
# Min C: 72.0 Max C: 79.0

# %% [markdown]
# Scores within the range 100 - 90 will B assigned A, 90 - 80 will be assigned B, and below 79 bwill be assigned C.

# %%
# Assign grade for each observation that has a score_sum value and has no grade score
index = scores_df[(scores_df['score_sum'].notnull()) & (scores_df['grade'].isnull())].index.to_list()

for idx in index:
    # If score is between 100 and 90 (both included) assign A grade
    if ((scores_df.iloc[idx,1] <= 100) &  (scores_df.iloc[idx,1] >= 90)): 
        scores_df.iloc[idx, 41] = 'A'
    # If score is between 90 and 80 (80 included) assign B grade  
    elif ((scores_df.iloc[idx,1] < 90) &  (scores_df.iloc[idx,1] >= 80)):
          scores_df.iloc[idx, 41] = 'B'
    # If score is below 80 assign C grade
    else:
          scores_df.iloc[idx, 41] = 'C'

# %%
# Investigate the entries of the seating column

seats_df = scores_df.dropna(subset = ['seats', 'rpt_area_desc'])
                            
# Create a plot of  seats by kind of establishments from scores_df.
fig, axes = plt.subplots(2, 1, figsize=(15,15), sharey = True)
sns.boxplot(x = 'seats', y = 'rpt_area_desc', data = seats_df, ax = axes[0])
sns.barplot(x = 'seats', y = 'rpt_area_desc', data = seats_df, ax = axes[1])

# Set title of each plot 
axes[0].set_title('Boxplot of Number of Seats in Types of Establishments')
axes[1].set_title('Barplot of Number of Seats in Types of Establishments')

# Set y-axis label of each plot 
axes[0].set_ylabel('Types of Establishments')
axes[1].set_ylabel('Types of Establishments')

# Set x-axis label of each plot 
axes[0].set_xlabel('Number of Seats')
axes[1].set_xlabel('Number of Seats')

# Set limit of x-axis
axes[0].set_xlim(0, 350)
axes[1].set_xlim(0, 350)

plt.show()

# %% [markdown]
# We observe that summer camps, daycares, adult day cares and food service, and day cares have the most capacity for customers. There are numerous outliers for foodservice according to the boxplot that are not captured in the barplot. Summer food, local confinements, tattoo establishments, swimming pools, mobile food, Bread&Breakfasts, lodgings and institutions do not have any seats recorded. This only makes sense for an establishment like mobile food where it is only a mobile kitchen without seating areas for customers. It was expected that other locations like would have more seating. It could be that the data was entered as zero as a default because the amount of seats was unknown.
#
# Due to the incomplete information on seating, this column will not be used for modelling.

# %%
# Drop null values from comments, grades, and score_sum and revaluate the number of null values
scores_df = scores_df.dropna(subset = ['comments', 'grade','score_sum'])
print_pctnull(scores_df)
# Out:
# verification_required_date: 100.0
# field59: 100.0
# rpt_area_num: 100.0
# action_code_id: 100.0
# permit_type_id: 100.0
# complaint_section: 100.0
# request_number: 100.0
# mileage: 100.0
# oss_id: 100.0
# void_date: 100.0
# epi_type_desc: 100.0
# person_incharge_lname: 100.0
# sample_attendance: 100.0
# inspection_reason_id: 100.0
# cdp_est_num: 100.0
# permit_status: 100.0
# oss_num: 100.0
# est_type_num: 100.0
# person_incharge_fname: 100.0
# com_num: 100.0
# inspection_reason_desc: 100.0
# action_code_desc: 100.0
# ehs_num: 100.0
# seats: 99.8
# biguanide_sum: 99.8
# est_group_desc: 99.6
# est_group_id: 99.6
# bromine_sum: 99.4
# smoking_allowed: 97.7
# water_temp_sum: 95.1
# num_rf_inter_viol: 85.8
# num_repeat_rf_inter_viol: 85.8
# classification_id: 80.9
# classification_desc: 80.9
# chlorine_sum: 78.7
# water_ph_sum: 78.3
# premise_name: 74.2
# group_code_id: 70.2
# end_inspection_ampm: 53.0
# end_time_of_inspection_mm: 52.9
# end_time_of_inspection_hh: 52.9
# image_file_name: 50.9
# image_file_path: 50.9
# time_of_inspection: 50.8
# ampm_of_inspection: 45.8
# time_of_inspection_mm: 40.9
# time_of_inspection_hr: 40.8
# travel_time_hrs: 21.1
# travel_time_min: 21.1
# inspection_time_hrs: 21.1
# inspection_time_min: 21.1
# update_user_id: 18.9
# lat: 0.0
# state_id: 0.0
# rpt_area_desc: 0.0
# followup_id: 0.0
# id: 0.0
# permit_status_id: 0.0
# geo_list: 0.0
# setup_date: 0.0
# sample: 0.0
# comment_sheet_id: 0.0
# sent_to_bets_yn: 0.0
# violations_id: 0.0
# index: 0.0
# six_point_demerit: 0.0
# ehs_id: 0.0
# score_sum: 0.0
# comments: 0.0
# delete_mark: 0.0
# epi_type_id: 0.0
# sewage: 0.0
# insp_type: 0.0
# type_description: 0.0
# insp_date: 0.0
# est_type: 0.0
# water: 0.0
# rpt_area_code: 0.0
# est_id: 0.0
# extra_credit: 0.0
# origin: 0.0
# geolocation: 0.0
# grade: 0.0
# county: 0.0
# update_date: 0.0
# ehs: 0.0
# district: 0.0
# territory: 0.0
# est_num: 0.0
# final_score_sum: 0.0
# lon: 0.0

# %% [markdown]
# Columns that have null values over 5% we will dropped from the dataframe.

# %%
# Create list of column names where percentage of null values are greater than 5%.

# Calculate the % null for each column
pct = round((scores_df.isnull().sum()/len(scores_df)*100),1).sort_values(ascending = False)

# Create dataframe and reset index where indices are column names and pct are the calculated values
pct_df = pd.DataFrame(pct.index, pct).reset_index()

# Rename columns, with index as calculated column, pct_null, and 0 as column name, col_name.
pct_df = pct_df.rename(columns = {'index':'pct_null',0:'col_name'})

# From the dataframe drop column names corresponding to pct_nulls that are greater than 5%.
col_drop = pct_df['col_name'][pct_df['pct_null'] > 5]

# Convert the columns to a list.
col_drop = col_drop.to_list()

# %%
# Drop col_drop columns from scores_df
scores_df = scores_df.drop(columns = col_drop)

# %%
# Drop additional redundant columns of columns that do not add information, or not understood

scores_df = scores_df.drop(columns = ['index','delete_mark','epi_type_id','insp_type','est_type', 'est_id', 'origin','geolocation', 'county', 'update_date',\
'district', 'final_score_sum','state_id', 'sample', 'comment_sheet_id', 'sent_to_bets_yn','id','violations_id',\
'setup_date', 'followup_id', 'geo_list'])

# %%
# Convert inspection date column to datetime format
scores_df['insp_date']= pd.to_datetime(scores_df['insp_date'])

# %%
# Create month and year columns for scores_df from the insp_date column to investigate how inspection scores vary by year.
scores_df['year'] = scores_df['insp_date'].dt.year
scores_df['month'] = scores_df['insp_date'].dt.month

# %%
# Group the dataframe by type of establishment and year, and calculate the inspection score for these groupings.
time_trend_group = pd.DataFrame(scores_df.groupby(['rpt_area_desc','year'])['score_sum'].mean()).reset_index()

# %%
# Plot average inspection score by year for each type of establishment.
g = sns.FacetGrid(time_trend_group, row = 'rpt_area_desc', margin_titles = True, height = 3, aspect = 3)
g.map(sns.lineplot, "year", "score_sum")
# Out:
# C:\Users\fabby\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# From the plots it seems places that mainly serve food or have an aspect of food service have high inspection scores. There are no inspection scores observed for tattoo establishments. It is unlikely that tattoo parlors have inspection scores of zero. The entry could have been made if the value was low. Other establishments have low scores as well but it is difficult to verify whether they are incorrect entries or not. They will be kept as is until additional information is given.

# %% [markdown]
# # Word Processing
#
# Remove punctuation from comments column and standardize the case to lower case.

# %%
# Remove comments from the comments column of the dataframe.
scores_df['text'] = [re.sub("[^A-Za-z]"," ",string) for string in scores_df.comments]
scores_df['text'] = scores_df['text'].str.lower()

# %% [markdown]
# Tfidf Vectorizer will be used to vectorize the words in each column and treat each column as a 'document' in a collection of documents. Once the columns are vectorized, a word cloud will be created for each type of establishment.

# %%
# Create a set of stop words
stop_words = set(stopwords.words('english'))

# Initiate the wordnetlemmatizer function
wnl = WordNetLemmatizer() 


# Create tokens from the text column strings
scores_df['tokens'] =  scores_df.apply(lambda row: word_tokenize(row['text']), axis = 1 )

# Remove stopwords
scores_df['tokens'] =  scores_df.apply(lambda row: [word for word in row['tokens']\
                                                                          if word not in stop_words], axis = 1)
# Create lemmas
scores_df['lemmas'] = scores_df.apply(lambda row: [wnl.lemmatize(word) for word in\
                                                                              row['tokens']], axis = 1)

# Form lemmas into a full string
scores_df['lemmas'] = scores_df.apply(lambda row: ' '.join(row['lemmas']), axis = 1)

# %%
# Creat word clouds by type of establishment

# Create a list of establishments
scores_est = list(scores_df['rpt_area_desc'].unique())
        
# Run word cloud function on scores df
create_wordcloud(scores_df, scores_est, 'lemmas')

# %%
# Inspect datatypes in scores_df
scores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10957 entries, 1432 to 112045
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   score_sum          10957 non-null  float64
#  1   comments           10957 non-null  object
#  2   sewage             10957 non-null  int64
#  3   type_description   10957 non-null  object
#  4   insp_date          10957 non-null  datetime64[ns]
#  5   water              10957 non-null  int64
#  6   rpt_area_code      10957 non-null  int64
#  7   extra_credit       10957 non-null  object
#  8   grade              10957 non-null  object
#  9   ehs                10957 non-null  int64
#  10  territory          10955 non-null  float64
#  11  est_num            10956 non-null  float64
#  12  ehs_id             10957 non-null  int64
#  13  six_point_demerit  10957 non-null  object
#  14  permit_status_id   10957 non-null  float64
#  15  rpt_area_desc      10957 non-null  object
#  16  lat                10957 non-null  object
#  17  lon                10957 non-null  object
#  18  year               10957 non-null  int32
#  19  month              10957 non-null  int32
#  20  text               10957 non-null  object
#  21  tokens             10957 non-null  object
#  22  lemmas             10957 non-null  object
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(5), object(11)
# memory usage: 1.9+ MB

# %%
# Create dummy variables for features which are not target features, floats, or redundant features. Note text and
# token columns will be deleted later, while lemmas will be vectorized.

# Complete one hot encoding of object features that are not targets or to be used in analysis.
scores_df_dummy = pd.get_dummies(scores_df,columns = ['type_description','extra_credit', 'six_point_demerit', 'rpt_area_desc'],\
                                drop_first = True, prefix = 'D')

# %%
# Initiate tfidfvectorizer
tv = TfidfVectorizer(max_features = 200, stop_words = 'english')

# Fit and transform the text column
tv.fit(scores_df_dummy['lemmas'])
train_tv_transformedsc = tv.transform(scores_df_dummy['lemmas'])

# Create array of transformed text
train_tv_dfsc = pd.DataFrame(train_tv_transformedsc.toarray(), columns = tv.get_feature_names_out()).add_prefix('TFIDF_')

# Equate indices to void creation of Nan rows during concatination
scores_df_dummy.index = train_tv_dfsc.index

scores_df = pd.concat([scores_df_dummy, train_tv_dfsc], axis = 1, sort = False)

# %%
# Examine the data
examine_rowsc = train_tv_dfsc.iloc[0]
print(examine_rowsc.sort_values(ascending = False).head(3))
# Out:
# TFIDF_solution    0.356786
# TFIDF_toilet      0.311644
# TFIDF_degree      0.309207
# Name: 0, dtype: float64

# %%
# Convert 'lat' and 'lon' to float type
# Remove any character that is not a digit or '.' from each column lat
#scores_df['lat'] =  scores_df.apply(lambda row: [''.join(char for char in row['lat'] if char.isdigit() or char == '.')],\
                                                 #axis = 1)

# Remove any character that is not a digit or '.' from each column lon    
#scores_df['lon'] =  scores_df.apply(lambda row: [''.join(char for char in row['lon'] if char.isdigit() or char == '.')],\
                                                 #axis = 1)   

#Convert lat and long columns to float type
#scores_df['lat'] = scores_df['lat'].astype(float)
#scores_df['lon'] = scores_df['lon'].astype(float)

# %% [markdown]
# Found that numerous rows in lat and lon columns were empty despite being represented as not having null values. This is brining up errors when attempting to convert columns to float type. Both columns will be dropped and rpt_area_code (phone area code) will be used as a corollary for location. We will also drop text and token columns.

# %%
# Equate indices to void creation of Nan rows during concatination
#scores_df_dummy.index = scores_df.index

# Concatenate scores_df_dummy with scores df
#final_scoresdf = pd.concat([scores_df,scores_df_dummy], axis = 1 )

# Drop lon, lat, comment associated columns,insp_date, and grades from final_scoresdf, and those turned into
# dummy variables.
# We will only use inspection scores for the target variable, not grades.
final_scoresdf = scores_df.drop(columns = ['lat', 'lon', 'text', 'tokens', 'comments','lemmas','grade',\
                                          'insp_date'])

# %%
final_scoresdf.isna().sum().sort_values()
# Out:
# score_sum             0
# TFIDF_permit          0
# TFIDF_phone           0
# TFIDF_place           0
# TFIDF_placed          0
#                      ..
# TFIDF_disinfectant    0
# TFIDF_correct         0
# TFIDF_year            0
# est_num               1
# territory             2
# Length: 233, dtype: int64

# %%
final_scoresdf = final_scoresdf.dropna()

# %%
final_scoresdf.isna().sum().sort_values()
# Out:
# score_sum             0
# TFIDF_permit          0
# TFIDF_phone           0
# TFIDF_place           0
# TFIDF_placed          0
#                      ..
# TFIDF_discussed       0
# TFIDF_dish            0
# TFIDF_disinfectant    0
# TFIDF_correct         0
# TFIDF_year            0
# Length: 233, dtype: int64

# %%
# Split final_scoresdf into  X and y (inspection scores) components. 

# Convert score_sum column to string and create new target variable, y_sc for Formatted_FC_section
y = final_scoresdf['score_sum']

# Create a new feature variable that contains all independent features by dropping target variables score_sum and grade
X = final_scoresdf.drop(columns = ['score_sum'])

# Split data into test and training set for predicting inspection scores
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Scale the numerical features of the dataframe using StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
col_names = X_test.columns
pd.DataFrame(col_names).to_csv('col_names.csv')

# %%
# Store X_train_scaled, X_test_scaled, y_train, and y_test as csv files that can be read in during the modelling phase.
pd.DataFrame(X_train_scaled).to_csv('Xtrain_scaled.csv')
pd.DataFrame(X_test_scaled).to_csv('Xtest_scaled.csv')
pd.DataFrame(y_train).to_csv('y_train.csv')
pd.DataFrame(y_test).to_csv('y_test.csv')
pd.DataFrame(col_names).to_csv('col_names.csv')

# %% [markdown]
# The training and test sets generated will be used in the modelling step.
